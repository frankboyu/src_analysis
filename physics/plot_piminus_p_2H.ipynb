# %%
fig, ax = plt.subplots(1, 5, figsize=(25, 5), dpi=100)
ax[0].set_title("$6-7 GeV$")
ax[1].set_title("$7-8 GeV$")
ax[2].set_title("$8-9 GeV$")
ax[3].set_title("$9-10 GeV$")
ax[4].set_title("$10-11 GeV$")

for i in range(5):
    plt.axes(ax[i])
    plt.xlabel("$-t/GeV^2$")
    plt.ylabel("$d\sigma/dt (nb/GeV^2)$")
    plt.yscale('log')
    plt.ylim(1e-3, 1e5)
    plt.xlim(0,15)
        
    plt.errorbar(points_abst, cs[i], xerr=widths_abst, yerr=cs_error[i], marker='.', fmt='o')

# %%
plt.rcParams['figure.dpi'] = 200
plt.xlabel("$-t/GeV^2$")
plt.ylabel("ratio")
plt.title("charged pion ratio at $E_\gamma$ = 7.5 GeV")
plt.xlim(0,14)
plt.plot(points_anderson, pion_ratio)
